# %%
import pandas as pd
import seaborn as sns

# %%
phool=sns.load_dataset('iris')
phool
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
phool.sample(30)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 31            5.4          3.4           1.5          0.4      setosa
# 130           7.4          2.8           6.1          1.9   virginica
# 83            6.0          2.7           5.1          1.6  versicolor
# 5             5.4          3.9           1.7          0.4      setosa
# 36            5.5          3.5           1.3          0.2      setosa
# 133           6.3          2.8           5.1          1.5   virginica
# 125           7.2          3.2           6.0          1.8   virginica
# 142           5.8          2.7           5.1          1.9   virginica
# 110           6.5          3.2           5.1          2.0   virginica
# 27            5.2          3.5           1.5          0.2      setosa
# 90            5.5          2.6           4.4          1.2  versicolor
# 58            6.6          2.9           4.6          1.3  versicolor
# 139           6.9          3.1           5.4          2.1   virginica
# 59            5.2          2.7           3.9          1.4  versicolor
# 135           7.7          3.0           6.1          2.3   virginica
# 72            6.3          2.5           4.9          1.5  versicolor
# 77            6.7          3.0           5.0          1.7  versicolor
# 50            7.0          3.2           4.7          1.4  versicolor
# 55            5.7          2.8           4.5          1.3  versicolor
# 87            6.3          2.3           4.4          1.3  versicolor
# 42            4.4          3.2           1.3          0.2      setosa
# 121           5.6          2.8           4.9          2.0   virginica
# 96            5.7          2.9           4.2          1.3  versicolor
# 95            5.7          3.0           4.2          1.2  versicolor
# 17            5.1          3.5           1.4          0.3      setosa
# 35            5.0          3.2           1.2          0.2      setosa
# 113           5.7          2.5           5.0          2.0   virginica
# 67            5.8          2.7           4.1          1.0  versicolor
# 43            5.0          3.5           1.6          0.6      setosa
# 122           7.7          2.8           6.7          2.0   virginica

# %%
phool[phool['petal_length']>6]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 105           7.6          3.0           6.6          2.1  virginica
# 107           7.3          2.9           6.3          1.8  virginica
# 109           7.2          3.6           6.1          2.5  virginica
# 117           7.7          3.8           6.7          2.2  virginica
# 118           7.7          2.6           6.9          2.3  virginica
# 122           7.7          2.8           6.7          2.0  virginica
# 130           7.4          2.8           6.1          1.9  virginica
# 131           7.9          3.8           6.4          2.0  virginica
# 135           7.7          3.0           6.1          2.3  virginica

# %%
phool.species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
num=pd.Series([1,2,3,4,5.7,6])
num
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# 4    5.7
# 5    6.0
# dtype: float64

# %%
dates=pd.date_range("20240101",periods=6)
dates
# Out:
# DatetimeIndex(['2024-01-01', '2024-01-02', '2024-01-03', '2024-01-04',
#                '2024-01-05', '2024-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
import numpy as np
df=pd.DataFrame(np.random.rand(6,4),index=dates,columns=list("ABCD"))
df
# Out:
#                    A         B         C         D
# 2024-01-01  0.222663  0.731508  0.744760  0.289661
# 2024-01-02  0.117368  0.757782  0.988815  0.170656
# 2024-01-03  0.098265  0.865314  0.093647  0.313180
# 2024-01-04  0.299255  0.585258  0.935563  0.106316
# 2024-01-05  0.582980  0.386784  0.346273  0.275562
# 2024-01-06  0.944262  0.472433  0.993327  0.885507

# %%
df.dtypes
# Out:
# A    float64
# B    float64
# C    float64
# D    float64
# dtype: object

# %%
df.head(2)
# Out:
#                    A         B         C         D
# 2024-01-01  0.222663  0.731508  0.744760  0.289661
# 2024-01-02  0.117368  0.757782  0.988815  0.170656

# %%
df.tail(1)
# Out:
#                    A         B         C         D
# 2024-01-06  0.944262  0.472433  0.993327  0.885507

# %%
df.index
# Out:
# DatetimeIndex(['2024-01-01', '2024-01-02', '2024-01-03', '2024-01-04',
#                '2024-01-05', '2024-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df.sort_index(axis=0,ascending=False)
# Out:
#                    A         B         C         D
# 2024-01-06  0.944262  0.472433  0.993327  0.885507
# 2024-01-05  0.582980  0.386784  0.346273  0.275562
# 2024-01-04  0.299255  0.585258  0.935563  0.106316
# 2024-01-03  0.098265  0.865314  0.093647  0.313180
# 2024-01-02  0.117368  0.757782  0.988815  0.170656
# 2024-01-01  0.222663  0.731508  0.744760  0.289661

# %%
df.sort_values(by="B")
# Out:
#                    A         B         C         D
# 2024-01-05  0.582980  0.386784  0.346273  0.275562
# 2024-01-06  0.944262  0.472433  0.993327  0.885507
# 2024-01-04  0.299255  0.585258  0.935563  0.106316
# 2024-01-01  0.222663  0.731508  0.744760  0.289661
# 2024-01-02  0.117368  0.757782  0.988815  0.170656
# 2024-01-03  0.098265  0.865314  0.093647  0.313180

# %%
df[["A","B"]]
# Out:
#                    A         B
# 2024-01-01  0.222663  0.731508
# 2024-01-02  0.117368  0.757782
# 2024-01-03  0.098265  0.865314
# 2024-01-04  0.299255  0.585258
# 2024-01-05  0.582980  0.386784
# 2024-01-06  0.944262  0.472433

# %%
df
# Out:
#                    A         B         C         D
# 2024-01-01  0.222663  0.731508  0.744760  0.289661
# 2024-01-02  0.117368  0.757782  0.988815  0.170656
# 2024-01-03  0.098265  0.865314  0.093647  0.313180
# 2024-01-04  0.299255  0.585258  0.935563  0.106316
# 2024-01-05  0.582980  0.386784  0.346273  0.275562
# 2024-01-06  0.944262  0.472433  0.993327  0.885507

# %%
df[0:3]
# Out:
#                    A         B         C         D
# 2024-01-01  0.222663  0.731508  0.744760  0.289661
# 2024-01-02  0.117368  0.757782  0.988815  0.170656
# 2024-01-03  0.098265  0.865314  0.093647  0.313180

# %%
df.loc[:,["A","B"]]
# Out:
#                    A         B
# 2024-01-01  0.222663  0.731508
# 2024-01-02  0.117368  0.757782
# 2024-01-03  0.098265  0.865314
# 2024-01-04  0.299255  0.585258
# 2024-01-05  0.582980  0.386784
# 2024-01-06  0.944262  0.472433

# %%
df.iloc[:7,0:4]
# Out:
#                    A         B         C         D
# 2024-01-01  0.222663  0.731508  0.744760  0.289661
# 2024-01-02  0.117368  0.757782  0.988815  0.170656
# 2024-01-03  0.098265  0.865314  0.093647  0.313180
# 2024-01-04  0.299255  0.585258  0.935563  0.106316
# 2024-01-05  0.582980  0.386784  0.346273  0.275562
# 2024-01-06  0.944262  0.472433  0.993327  0.885507

# %%
df
# Out:
#                    A         B         C         D
# 2024-01-01  0.222663  0.731508  0.744760  0.289661
# 2024-01-02  0.117368  0.757782  0.988815  0.170656
# 2024-01-03  0.098265  0.865314  0.093647  0.313180
# 2024-01-04  0.299255  0.585258  0.935563  0.106316
# 2024-01-05  0.582980  0.386784  0.346273  0.275562
# 2024-01-06  0.944262  0.472433  0.993327  0.885507

# %%
df.shape
# Out:
# (6, 4)

# %%
df.iloc[4]
# Out:
# A    0.582980
# B    0.386784
# C    0.346273
# D    0.275562
# Name: 2024-01-05 00:00:00, dtype: float64

# %%
df.iloc[0:3,0:4]
# Out:
#                    A         B         C         D
# 2024-01-01  0.222663  0.731508  0.744760  0.289661
# 2024-01-02  0.117368  0.757782  0.988815  0.170656
# 2024-01-03  0.098265  0.865314  0.093647  0.313180

# %%
df.loc[:,["A","B","C"]]
# Out:
#                    A         B         C
# 2024-01-01  0.222663  0.731508  0.744760
# 2024-01-02  0.117368  0.757782  0.988815
# 2024-01-03  0.098265  0.865314  0.093647
# 2024-01-04  0.299255  0.585258  0.935563
# 2024-01-05  0.582980  0.386784  0.346273
# 2024-01-06  0.944262  0.472433  0.993327

# %%
df.iloc[3:6,2:3]
# Out:
#                    C
# 2024-01-04  0.935563
# 2024-01-05  0.346273
# 2024-01-06  0.993327

# %%
sns.catplot(data=phool)
